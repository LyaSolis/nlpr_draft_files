# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import shutil
shutil.copytree("/content/drive/MyDrive/GitHub/java-employee-challenge", "./java-employee-challenge")
# Out:
# './java-employee-challenge'

# %%
# %%bash
# source "/root/.sdkman/bin/sdkman-init.sh"

# %%
# %%bash
# sdk list java
# Out:
# bash: line 1: sdk: command not found

# %%
sdk list java
# Out:
#   File "<ipython-input-7-bfb85bd72ba7>", line 1
#     sdk list java
#            ^
# SyntaxError: invalid syntax

# %%
# Out:
# /bin/bash: sdk: command not found

# %%
# !ls /content/drive/MyDrive/GitHub/bluebert
# Out:
# 1_data_prep.ipynb  elmo		mribert      README.md
# bert		   LICENSE.txt	mt-bluebert  requirements.txt
# bluebert	   mlm_output	NER_output   tokenizer

# %%
output_dir = '/content/drive/MyDrive/GitHub/bluebert/mlm_output/'
model_to_save = model.module if hasattr(model, 'module') else model
model_to_save.save_pretrained(output_dir)
